# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.linear_model import LogisticRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Red%20Wine/winequality-red.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#Note- There are no nan values. There are some outliers and gap between Q3 and max values in some column .

# %%
#lets see how data is distributed for every column.

# %%
plt.figure(figsize=(20,15), facecolor='red')
plotnumber = 1

for column in data:
    if plotnumber<=12:
        ax = plt.subplot(6,2,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %%
#We can see some skewness in  the data . Let's deal with that data.

# %%
df_features = data.drop('quality',axis=1)

# %%
plt.figure(figsize=(20,15), facecolor='red')
graph = 1

for column in data:
    if graph<=12:
        plt.subplot(4,3,graph)
        ax=sns.boxplot(data=df_features[column])
        plt.xlabel(column,fontsize=20)
        
    graph+=1
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'quality'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 7
# ...

# %%
# Finding inter quartile range to identify outliers.

q1 = data.quantile(0.25)

q3 = data.quantile(0.75)

iqr = q3-q1

# %%
q1
# Out:
# fixed acidity            7.1000
# volatile acidity         0.3900
# citric acid              0.0900
# residual sugar           1.9000
# chlorides                0.0700
# free sulfur dioxide      7.0000
# total sulfur dioxide    22.0000
# density                  0.9956
# pH                       3.2100
# sulphates                0.5500
# alcohol                  9.5000
# quality                  5.0000
# Name: 0.25, dtype: float64

# %%
#We are going to remove the ouliers which we found

# %%
fixed_high = (q3['fixed acidity'] + (1.5 * iqr['fixed acidity']))
fixed_high
# Out:
# 12.349999999999998

# %%
index_1 = np.where(data['fixed acidity'] > fixed_high)
index_1
# Out:
# (array([ 205,  206,  243,  244,  264,  294,  328,  338,  339,  347,  353,
#          359,  363,  364,  366,  374,  381,  391,  394,  409,  429,  440,
#          442,  446,  470,  472,  509,  510,  516,  538,  544,  548,  554,
#          555,  557,  559,  560,  564,  565,  596,  599,  601,  603,  611,
#          652,  680,  811,  814, 1224], dtype=int64),)

# %%
data = data.drop(data.index[index_1])
data.shape
# Out:
# (1550, 12)

# %%
data.reset_index()
# Out:
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1545   1594            6.2             0.600         0.08             2.0
# 1546   1595            5.9             0.550         0.10             2.2
# 1547   1596            6.3             0.510         0.13             2.3
# 1548   1597            5.9             0.645         0.12             2.0
# 1549   1598            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
volatile_high = (q3['volatile acidity'] + (1.5 * iqr['volatile acidity']))
print (volatile_high)

index_2 = np.where(data['volatile acidity'] >volatile_high)

data = data.drop(data.index[index_2])
print (data.shape)

data.reset_index()
# Out:
# 1.0150000000000001
# (1531, 12)
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1526   1594            6.2             0.600         0.08             2.0
# 1527   1595            5.9             0.550         0.10             2.2
# 1528   1596            6.3             0.510         0.13             2.3
# 1529   1597            5.9             0.645         0.12             2.0
# 1530   1598            6.0             0.310         0.47             3.6
#
# ...

# %%
residual_high = (q3['residual sugar'] + (1.5 * iqr['residual sugar']))
print (residual_high)

index_3 = np.where(data['residual sugar'] >residual_high)

data = data.drop(data.index[index_3])
print (data.shape)

data.reset_index()
# Out:
# 3.6500000000000004
# (1393, 12)
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1388   1594            6.2             0.600         0.08             2.0
# 1389   1595            5.9             0.550         0.10             2.2
# 1390   1596            6.3             0.510         0.13             2.3
# 1391   1597            5.9             0.645         0.12             2.0
# 1392   1598            6.0             0.310         0.47             3.6
#
# ...

# %%
chlo_high = (q3['chlorides'] + (1.5 * iqr['chlorides']))
print (chlo_high)

index_2 = np.where(data['chlorides'] >chlo_high)

data = data.drop(data.index[index_2])
print (data.shape)

data.reset_index()
# Out:
# 0.11999999999999998
# (1311, 12)
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1306   1594            6.2             0.600         0.08             2.0
# 1307   1595            5.9             0.550         0.10             2.2
# 1308   1596            6.3             0.510         0.13             2.3
# 1309   1597            5.9             0.645         0.12             2.0
# 1310   1598            6.0             0.310         0.47             3.6
#
# ...

# %%
free_high = (q3['free sulfur dioxide'] + (1.5 * iqr['free sulfur dioxide']))
print (free_high)

index_3 = np.where(data['free sulfur dioxide'] >free_high)

data = data.drop(data.index[index_3])
print (data.shape)

data.reset_index()
# Out:
# 42.0
# (1295, 12)
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1290   1594            6.2             0.600         0.08             2.0
# 1291   1595            5.9             0.550         0.10             2.2
# 1292   1596            6.3             0.510         0.13             2.3
# 1293   1597            5.9             0.645         0.12             2.0
# 1294   1598            6.0             0.310         0.47             3.6
#
# ...

# %%
total_high = (q3['total sulfur dioxide'] + (1.5 * iqr['total sulfur dioxide']))
print (total_high)

index_4 = np.where(data['total sulfur dioxide'] > total_high)

data = data.drop(data.index[index_4])
print (data.shape)

data.reset_index()
# Out:
# 122.0
# (1259, 12)
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1254   1594            6.2             0.600         0.08             2.0
# 1255   1595            5.9             0.550         0.10             2.2
# 1256   1596            6.3             0.510         0.13             2.3
# 1257   1597            5.9             0.645         0.12             2.0
# 1258   1598            6.0             0.310         0.47             3.6
#
# ...

# %%
den_low = (q1['density'] - (1.5 * iqr['density']))
print (den_low)

index_5 = np.where(data['density'] < den_low)

data = data.drop(data.index[index_5])
print (data.shape)

data.reset_index()
# Out:
# 0.9922475000000001
# (1241, 12)
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1236   1594            6.2             0.600         0.08             2.0
# 1237   1595            5.9             0.550         0.10             2.2
# 1238   1596            6.3             0.510         0.13             2.3
# 1239   1597            5.9             0.645         0.12             2.0
# 1240   1598            6.0             0.310         0.47             3.6
#
# ...

# %%
den_high = (q3['density'] + (1.5 * iqr['density']))
print (den_high)

index_6 = np.where(data['density'] > den_high)

data = data.drop(data.index[index_6])
print (data.shape)

data.reset_index()
# Out:
# 1.0011875
# (1241, 12)
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1236   1594            6.2             0.600         0.08             2.0
# 1237   1595            5.9             0.550         0.10             2.2
# 1238   1596            6.3             0.510         0.13             2.3
# 1239   1597            5.9             0.645         0.12             2.0
# 1240   1598            6.0             0.310         0.47             3.6
#
# ...

# %%
ph_high = (q3['pH'] + (1.5 * iqr['pH']))
print (ph_high)

index_7 = np.where(data['pH'] > ph_high)

data = data.drop(data.index[index_7])
print (data.shape)

data.reset_index()
# Out:
# 3.6849999999999996
# (1226, 12)
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1221   1594            6.2             0.600         0.08             2.0
# 1222   1595            5.9             0.550         0.10             2.2
# 1223   1596            6.3             0.510         0.13             2.3
# 1224   1597            5.9             0.645         0.12             2.0
# 1225   1598            6.0             0.310         0.47             3.6
#
# ...

# %%
ph_low = (q1['pH'] - (1.5 * iqr['pH']))
print (ph_low)

index_8 = np.where(data['pH'] < ph_low)

data = data.drop(data.index[index_8])
print (data.shape)

data.reset_index()
# Out:
# 2.925
# (1222, 12)
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1217   1594            6.2             0.600         0.08             2.0
# 1218   1595            5.9             0.550         0.10             2.2
# 1219   1596            6.3             0.510         0.13             2.3
# 1220   1597            5.9             0.645         0.12             2.0
# 1221   1598            6.0             0.310         0.47             3.6
#
# ...

# %%
sul_high = (q3['sulphates'] + (1.5 * iqr['sulphates']))
print (sul_high)

index_9 = np.where(data['sulphates'] > sul_high)

data = data.drop(data.index[index_9])
print (data.shape)

data.reset_index()
# Out:
# 0.9999999999999999
# (1202, 12)
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1197   1594            6.2             0.600         0.08             2.0
# 1198   1595            5.9             0.550         0.10             2.2
# 1199   1596            6.3             0.510         0.13             2.3
# 1200   1597            5.9             0.645         0.12             2.0
# 1201   1598            6.0             0.310         0.47             3.6
#
# ...

# %%
alc_high = (q3['alcohol'] + (1.5 * iqr['alcohol']))
print (alc_high)

index_9 = np.where(data['alcohol'] > alc_high)

data = data.drop(data.index[index_9])
print (data.shape)

data.reset_index()
# Out:
# 13.5
# (1200, 12)
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1195   1594            6.2             0.600         0.08             2.0
# 1196   1595            5.9             0.550         0.10             2.2
# 1197   1596            6.3             0.510         0.13             2.3
# 1198   1597            5.9             0.645         0.12             2.0
# 1199   1598            6.0             0.310         0.47             3.6
#
# ...

# %%
ch_low = (q1['chlorides'] - (1.5 * iqr['chlorides']))
print (ch_low)

index_8 = np.where(data['chlorides'] < ch_low)

data = data.drop(data.index[index_8])
print (data.shape)

data.reset_index()
# Out:
# 0.04000000000000002
# (1194, 12)
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1189   1594            6.2             0.600         0.08             2.0
# 1190   1595            5.9             0.550         0.10             2.2
# 1191   1596            6.3             0.510         0.13             2.3
# 1192   1597            5.9             0.645         0.12             2.0
# 1193   1598            6.0             0.310         0.47             3.6
#
# ...

# %%
# We are now left with 1194 rows. Now time to check distribution of data through a graph.

# %%
plt.figure(figsize=(20,15), facecolor='red')
plotnumber = 1

for column in data:
    if plotnumber<=12:
        ax = plt.subplot(6,2,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %%
# Finding the relationships. keeping data which have relationship with label.

# %%
# Feature Selection

# %%
x = data.drop(columns = ['quality'])
y = data['quality']

# %%
plt.figure(figsize = (15,20))
plotnumber = 1

for column in x:
    if plotnumber <=12 :
        ax = plt.subplot(6,2, plotnumber)
        sns.scatterplot(x=y,y=x[column],hue=y)
    plotnumber+=1
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Standard Scaler

# %%
scalar = StandardScaler()
x_scaled = scalar.fit_transform(x)

# %%
x_scaled.shape[1]
# Out:
# 11

# %%
vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]
vif["Features"] = x.columns

vif
# Out:
#          vif              Features
# 0   6.796263         fixed acidity
# 1   2.032933      volatile acidity
# 2   3.139208           citric acid
# 3   1.718704        residual sugar
# 4   1.295224             chlorides
# 5   1.813119   free sulfur dioxide
# 6   2.039186  total sulfur dioxide
# 7   6.703952               density
# 8   3.089825                    pH
# 9   1.324893             sulphates
# 10  3.645844               alcohol

# %%
# there are no multicollinearity

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y, test_size = 0.25, random_state = 355)

# %%
# MODEL BUILDING

# %%
regression = LinearRegression()
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
data.tail(2)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1597     10.2        5
# 1598     11.0        6

# %%
regression.predict(scalar.transform([[6.0, 0.310, 0.47, 3.6, 0.067, 18.0, 42.0, 0.99549, 3.39, 0.66, 11.0]]))
# Out:
# array([5.97789529])

# %%
# How our model perform with test data .

# %%
regression.score(x_test,y_test)
# Out:
# 0.38113760074176706

# %%
regression.score(x_train,y_train)
# Out:
# 0.3940493338934421
